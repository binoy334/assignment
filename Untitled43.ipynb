# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\Akhil\Desktop\data\New folder\myexcel - myexcel.csv.csv")
data.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data['height'] = np.random.randint(150, 181, size=len(data))
print(data)
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary  height
# 0                Texas  7730337.0     169
# ...

# %%
#1 Distribution of employees across each team

team_counts = data['Team'].value_counts()
team_percentages = (team_counts / len(data)) * 100
print("Distribution of employees across each team:")
print(team_percentages)
plt.figure(figsize=(12, 8))
team_counts.plot(kind='bar')
plt.xlabel('Team')
plt.ylabel('Number of Employees')
# Out:
# Distribution of employees across each team:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# ...

# %%
#2
position_counts = data['Position'].value_counts()
print(position_counts)
plt.figure(figsize=(12, 8))
position_counts.plot(kind='bar')
plt.xlabel('Position')
plt.ylabel('Number of Employees')
plt.title('Distribution of Employees by Position')
plt.xticks(rotation=45)
plt.show()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
#3
age_groups = data['Age'].value_counts(bins=[20, 30, 40, 50, 60])
print("Predominant age group among employees:")
print(age_groups)
# Out:
# Predominant age group among employees:
# (19.999, 30.0]    365
# (30.0, 40.0]       91
# (40.0, 50.0]        0
# (50.0, 60.0]        0
# Name: count, dtype: int64

# %%
#4
plt.figure(figsize=(10,6))
plt.bar(position_salary['Position'].head(5), position_salary['Salary'].head(5))
plt.xlabel('Position')
plt.ylabel('Salary')
plt.title('Top 5 Positions with the Highest Salary Expenditure')
plt.show()

# %%
#5
plt.figure(figsize=(10,6))
plt.scatter(data['Age'], data['Salary'])
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Relationship between Age and Salary')
plt.show()

# %%
##1
# Graphical Representation
plt.figure(figsize=(10,6))
plt.bar(position_salary['Position'].head(), position_salary['Salary'].head())
plt.xlabel('Position')
plt.ylabel('Salary')
plt.title('Top  Positions with the Highest Salary Expenditure')
plt.show()

# %%
##2
plt.figure(figsize=(10,6))
plt.scatter(data['Age'], data['Salary'])
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Relationship between Age and Salary')
plt.show()

# %%
##3
plt.figure(figsize=(10,6))
plt.hist(data['Salary'], bins=50)
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.title('Distribution of Salaries')
plt.show()

# %%
##4
team_avg_salary = data.groupby('Team')['Salary'].mean().reset_index()

plt.figure(figsize=(10,6))
plt.bar(team_avg_salary['Team'], team_avg_salary['Salary'])
plt.xlabel('Team')
plt.ylabel('Average Salary')
plt.title('Average Salary of Different Teams')
plt.show()

# %%
# data story
# Plot the salary distribution
plt.figure(figsize=(10,6))
plt.hist(data['Salary'], bins=50)
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.title('Salary Distribution')
plt.show()

# %%
##data story:
#position_salary = data.groupby('Position')['Salary'].sum().reset_index()
position_salary = position_salary.sort_values(by='Salary', ascending=False)
plt.figure(figsize=(10,6))
plt.bar(position_salary['Position'].head(5), position_salary['Salary'].head(5))
plt.xlabel('Position')
plt.ylabel('Salary')
plt.title('Top 5 Positions with the Highest Salary Expenditure')
plt.show()
